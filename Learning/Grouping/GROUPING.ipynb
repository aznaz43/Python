# %% [markdown]
# >**GROUPING**

# %% [markdown]
# proses mengelompokkan data pada dataframe tertentu menggunakan *method* groupby() berdasarkan agregasi tertentu, seperti mean, sum, median dll.

# %% [markdown]
# > **PERSIAPAN DATASET**
#
# dataset yang digunakan : https://www.kaggle.com/datasets/xontoloyo/data-penjualan-zara

# %%
import pandas as pd

data=pd.read_csv("zara.csv", sep=";")
data
# Out:
#     Product Position Product Category Seasonal  Sales Volume  \
# 0              Aisle         Clothing       No          2823
# 1              Aisle         Clothing       No           654
# 2            End-cap         Clothing      Yes          2220
# 3              Aisle         Clothing      Yes          1568
# 4            End-cap         Clothing      Yes          2942
# ..               ...              ...      ...           ...
# 247   Front of Store         Clothing       No          1014
# 248            Aisle         Clothing       No          2222
# 249            Aisle         Clothing      Yes          2534
# 250   Front of Store         Clothing      Yes          1466
# 251   Front of Store         Clothing      Yes          2870
#
#                                               name  price    terms section  \
# 0                              BASIC PUFFER JACKET  19,99  jackets     MAN
# 1                                    TUXEDO JACKET    169  jackets     MAN
# 2                             SLIM FIT SUIT JACKET    129  jackets     MAN
# 3                              STRETCH SUIT JACKET    129  jackets     MAN
# 4                              DOUBLE FACED JACKET    139  jackets     MAN
# ..                                             ...    ...      ...     ...
# 247  FAUX LEATHER OVERSIZED JACKET LIMITED EDITION    169  jackets     MAN
# 248              CONTRASTING PATCHES BOMBER JACKET    159  jackets     MAN
# 249                            PATCH BOMBER JACKET  12,99  jackets     MAN
# 250          CROPPED BOMBER JACKET LIMITED EDITION   19,9  jackets     MAN
# 251                     FAUX LEATHER PUFFER JACKET   39,9  jackets     MAN
#
#       revenue
# 0    56431,77
# 1      110526
# 2      286380
# 3      202272
# 4      408938
# ..        ...
# 247    171366
# 248    353298
# 249  32916,66
# 250   29173,4
# 251    114513
#
# [252 rows x 9 columns]

# %% [markdown]
# > **IDENTIFIKASI MISSING VALUE**

# %%
data.isna().sum()
# Out:
# Product Position    0
# Product Category    0
# Seasonal            0
# Sales Volume        0
# name                1
# price               0
# terms               0
# section             0
# revenue             0
# dtype: int64

# %% [markdown]
# **MENGHAPUS BARIS YANG MENGANDUNG MISSING VALUES**

# %%
# menghapus baris yang mengandung missing value pada kolom name
data.dropna(subset=["name"], axis=0, inplace=True)

# mereset index karena ada data terhapus
data.reset_index(drop=True, inplace=True)

data
# Out:
#     Product Position Product Category Seasonal  Sales Volume  \
# 0              Aisle         Clothing       No          2823
# 1              Aisle         Clothing       No           654
# 2            End-cap         Clothing      Yes          2220
# 3              Aisle         Clothing      Yes          1568
# 4            End-cap         Clothing      Yes          2942
# ..               ...              ...      ...           ...
# 246   Front of Store         Clothing       No          1014
# 247            Aisle         Clothing       No          2222
# 248            Aisle         Clothing      Yes          2534
# 249   Front of Store         Clothing      Yes          1466
# 250   Front of Store         Clothing      Yes          2870
#
#                                               name  price    terms section  \
# 0                              BASIC PUFFER JACKET  19,99  jackets     MAN
# 1                                    TUXEDO JACKET    169  jackets     MAN
# 2                             SLIM FIT SUIT JACKET    129  jackets     MAN
# 3                              STRETCH SUIT JACKET    129  jackets     MAN
# 4                              DOUBLE FACED JACKET    139  jackets     MAN
# ..                                             ...    ...      ...     ...
# 246  FAUX LEATHER OVERSIZED JACKET LIMITED EDITION    169  jackets     MAN
# 247              CONTRASTING PATCHES BOMBER JACKET    159  jackets     MAN
# 248                            PATCH BOMBER JACKET  12,99  jackets     MAN
# 249          CROPPED BOMBER JACKET LIMITED EDITION   19,9  jackets     MAN
# 250                     FAUX LEATHER PUFFER JACKET   39,9  jackets     MAN
#
#       revenue
# 0    56431,77
# 1      110526
# 2      286380
# 3      202272
# 4      408938
# ..        ...
# 246    171366
# 247    353298
# 248  32916,66
# 249   29173,4
# 250    114513
#
# [251 rows x 9 columns]

# %% [markdown]
# > **MEMERIKSA TIPE DATA**

# %%
data.dtypes
# Out:
# Product Position    object
# Product Category    object
# Seasonal            object
# Sales Volume         int64
# name                object
# price               object
# terms               object
# section             object
# revenue             object
# dtype: object

# %% [markdown]
# > **DATA FORMATTING**

# %% [markdown]
# **Mengubah Tipe Data Price dan Revenue Menjadi Numerik**

# %%
# mengubah koma pada angka menjadi titik
data["price"] = data["price"].astype(str).str.replace(",", ".", regex=True)
data["revenue"] = data["revenue"].astype(str).str.replace(",", ".", regex=True)

# mengubah tipe data menjadi numeric
data["price"] = pd.to_numeric(data["price"], errors="coerce")
data["revenue"] = pd.to_numeric(data["revenue"], errors="coerce")

data.dtypes
# Out:
# Product Position     object
# Product Category     object
# Seasonal             object
# Sales Volume          int64
# name                 object
# price               float64
# terms                object
# section              object
# revenue             float64
# dtype: object

# %% [markdown]
# > **GROUPING BERDASARKAN SATU KOLOM TERTENTU**

# %% [markdown]
# **Grouping berdasarkan "terms" dengan agresi "mean"**

# %%
data.groupby("terms")[['Sales Volume', 'price', 'revenue']].mean()
# Out:
#           Sales Volume     price      revenue
# terms
# jackets         257630  14677.11  26344713.87
# jeans            13320    511.39    864385.25
# shoes            57906   2011.08   3754837.63
# sweaters         75242   2249.37   4090631.48
# t-shirts         53637   2157.69   3696806.25

# %% [markdown]
# **Grouping berdasarkan "section" dengan agregasi "sum"**

# %%
data.groupby("section")[['Sales Volume', 'price', 'revenue']].sum()
# Out:
#          Sales Volume     price      revenue
# section
# MAN            394361  19888.76  35475561.03
# WOMAN           63374   1717.88   3275813.45

# %% [markdown]
# > **GROUPING BERDASARKAN DUA KOLOM TERTENTU**

# %% [markdown]
# **Grouping berdasarkan "product position" dan "section" dengan agregasi "sum"**

# %%
data.groupby(["Product Position","section"])[["Sales Volume", "price", "revenue"]].sum()
# Out:
#                           Sales Volume    price      revenue
# Product Position section
# Aisle            MAN            160038  8079.22  14566770.23
#                  WOMAN           17358   533.00    914668.20
# End-cap          MAN            127053  6220.07  11108643.71
#                  WOMAN           24039   640.70   1200720.10
# Front of Store   MAN            107270  5589.47   9800147.09
#                  WOMAN           21977   544.18   1160425.15

# %% [markdown]
# > **GROUPING BEBERAPA AGREGASI**

# %% [markdown]
# **Groping "Product position" dan "section" dengan agregasi "min" dan "max"**

# %%
data.groupby(["Product Position","section"])[["Sales Volume", "price", "revenue"]].agg(["min","max"])
# Out:
#                          Sales Volume        price          revenue
#                                   min   max    min    max       min       max
# Product Position section
# Aisle            MAN              654  2989   9.99  349.0  21888.15  649140.0
#                  WOMAN            558  2877  39.90   79.9  26728.20  172332.3
# End-cap          MAN              624  2968  12.99  299.0  22888.55  651521.0
#                  WOMAN            622  2901  35.90   69.9  31037.80  192924.0
# Front of Store   MAN              529  2870  12.99  439.0  27733.65  393843.0
#                  WOMAN            542  2778   7.99  169.0   4330.58  434668.0

# %% [markdown]
# **Grouping "Product Position" dengan agregasi "max" pada "sales volume" dan "mean" pada "revenue"**

# %%
data.groupby("Product Position").agg({"Sales Volume":"max", "revenue":"mean"})
# Out:
#                   Sales Volume        revenue
# Product Position
# Aisle                     2989  159602.458041
# End-cap                   2968  144816.044824
# Front of Store            2870  158848.873043

# %% [markdown]
# > **GROUPING DENGAN CUSTOM FUNCTION**

# %%
def selisih(x):
  return x.max() - x.min()
data.groupby("Product Position").agg({"Sales Volume" : "std", "revenue":selisih})
# Out:
#                   Sales Volume    revenue
# Product Position
# Aisle               711.114633  627251.85
# End-cap             672.153017  628632.45
# Front of Store      720.865152  430337.42
