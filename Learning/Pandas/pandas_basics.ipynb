# %% [markdown]
# **IMPORT DATA**
#
# dataset : https://www.kaggle.com/datasets/pinisetty/nike-sales-2024-data-analysis-using-excel

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

nike_sales = '/content/drive/MyDrive/Colab Notebooks/nike_sales_2024.csv'

try:
    df = pd.read_csv(nike_sales)
    print("Import Data Sukses")
    print("")
    display(df)
except FileNotFoundError:
    print(f"Error: File Tidak Ditemukan")
# Out:
# Import Data Sukses
#         Month         Region Main_Category Sub_Category       Product_Line  \
# 0    November          India     Equipment         Bags           Gym Sack
# 1     January          India     Equipment  Accessories               Hats
# 2     October          India       Apparel         Tops        Tech Fleece
# 3    December  Greater China      Footwear      Cricket      Vapor Cricket
# 4         May  Greater China     Equipment        Socks  Performance Socks
# ..        ...            ...           ...          ...                ...
# 995   October          India     Equipment  Accessories               Hats
# 996      July         Europe     Equipment        Socks  Performance Socks
# 997    August          Japan      Footwear     Football     Phantom Vision
# 998       May    South Korea     Equipment        Socks         Crew Socks
# 999  December          Japan      Footwear      Cricket      Vapor Cricket
#
# ...

# %% [markdown]
# **DIMENSI DATAFRAME**

# %%
df.shape
print(f"Data terdiri {df.shape[0]} baris dan {df.shape[1]} kolom")
# Out:
# Data terdiri 1000 baris dan 10 kolom

# %% [markdown]
# **MENAMPILKAN 5 DATA TERATAS**

# %%
df.head()
# Out:
#       Month         Region Main_Category Sub_Category       Product_Line  \
# 0  November          India     Equipment         Bags           Gym Sack
# 1   January          India     Equipment  Accessories               Hats
# 2   October          India       Apparel         Tops        Tech Fleece
# 3  December  Greater China      Footwear      Cricket      Vapor Cricket
# 4       May  Greater China     Equipment        Socks  Performance Socks
#
#   Price_Tier  Units_Sold  Revenue_USD  Online_Sales_Percentage  Retail_Price
# 0     Budget       48356     14506800                       73           300
# 1     Budget        9842      2066820                       50           210
# 2  Mid-Range       25079      1755530                       90            70
# 3    Premium       41404      8694840                       58           210
# 4    Premium       33569      5371040                       53           160

# %% [markdown]
# **MENAMPILKAN 5 DATA TERBAWAH**

# %%
df.tail()
# Out:
#         Month       Region Main_Category Sub_Category       Product_Line  \
# 995   October        India     Equipment  Accessories               Hats
# 996      July       Europe     Equipment        Socks  Performance Socks
# 997    August        Japan      Footwear     Football     Phantom Vision
# 998       May  South Korea     Equipment        Socks         Crew Socks
# 999  December        Japan      Footwear      Cricket      Vapor Cricket
#
#     Price_Tier  Units_Sold  Revenue_USD  Online_Sales_Percentage  Retail_Price
# 995  Mid-Range        9870       987000                       82           100
# 996  Mid-Range       14668      2640240                       88           180
# 997    Premium       15078      2261700                       74           150
# 998    Premium       26242      1312100                       52            50
# 999  Mid-Range       18133      5077240                       68           280

# %% [markdown]
# **MENAMPILKAN INFORMASI DATA**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Month                    1000 non-null   object
#  1   Region                   1000 non-null   object
#  2   Main_Category            1000 non-null   object
#  3   Sub_Category             1000 non-null   object
#  4   Product_Line             1000 non-null   object
#  5   Price_Tier               1000 non-null   object
#  6   Units_Sold               1000 non-null   int64
#  7   Revenue_USD              1000 non-null   int64
#  8   Online_Sales_Percentage  1000 non-null   int64
#  9   Retail_Price             1000 non-null   int64
# dtypes: int64(4), object(6)
# memory usage: 78.3+ KB

# %% [markdown]
# menunjukkan semua data non-null (tidak ada baris kosong)

# %% [markdown]
# MENAMPILKAN DESKRIPSI DATA

# %%
df.describe()
# Out:
#          Units_Sold   Revenue_USD  Online_Sales_Percentage  Retail_Price
# count   1000.000000  1.000000e+03              1000.000000    1000.00000
# mean   28498.951000  5.039576e+06                70.040000     176.32000
# std    12926.495678  3.267217e+06                11.748635      75.26169
# min     5028.000000  2.874000e+05                50.000000      50.00000
# 25%    17554.250000  2.344675e+06                60.000000     110.00000
# 50%    28685.000000  4.328020e+06                71.000000     180.00000
# 75%    40026.000000  7.264942e+06                80.000000     240.00000
# max    49992.000000  1.486470e+07                90.000000     300.00000

# %% [markdown]
# **MELAKUKAN AKSES PADA DATAFRAME**

# %%
#akses baris ke 1
df.iloc[1]
# Out:
# Month                          January
# Region                           India
# Main_Category                Equipment
# Sub_Category               Accessories
# Product_Line                      Hats
# Price_Tier                      Budget
# Units_Sold                        9842
# Revenue_USD                    2066820
# Online_Sales_Percentage             50
# Retail_Price                       210
# Name: 1, dtype: object

# %%
# akses baris ke 2 kolom ke 2

df.iloc[2,2]
# Out:
# 'Apparel'

# %%
# akses semua baris kolom ke-1

df.iloc[:,1]
# Out:
# 0              India
# 1              India
# 2              India
# 3      Greater China
# 4      Greater China
#            ...
# 995            India
# 996           Europe
# 997            Japan
# 998      South Korea
# 999            Japan
# Name: Region, Length: 1000, dtype: object

# %%
# akses baris ke-0 dan kolom ke-0 sampai kolom ke-5

df.iloc[0, :5]
# Out:
# Month             November
# Region               India
# Main_Category    Equipment
# Sub_Category          Bags
# Product_Line      Gym Sack
# Name: 0, dtype: object

# %%
# akses baris ke 1, 5, 10 dengan kolom 1

df.iloc[[1, 5, 10],1]
# Out:
# 1             India
# 5             Japan
# 10    Greater China
# Name: Region, dtype: object

# %%
# akses baris ke 10 terakhir

df.iloc[-10:]
# Out:
#          Month          Region Main_Category Sub_Category       Product_Line  \
# 990      April           Japan     Equipment  Accessories               Hats
# 991   December   Greater China      Footwear     Football     Phantom Vision
# 992      March           India      Footwear      Cricket      Vapor Cricket
# 993    October  Southeast Asia       Apparel  Performance   Compression Wear
# 994  September           Japan       Apparel         Tops        Tech Fleece
# 995    October           India     Equipment  Accessories               Hats
# 996       July          Europe     Equipment        Socks  Performance Socks
# 997     August           Japan      Footwear     Football     Phantom Vision
# 998        May     South Korea     Equipment        Socks         Crew Socks
# 999   December           Japan      Footwear      Cricket      Vapor Cricket
#
#     Price_Tier  Units_Sold  Revenue_USD  Online_Sales_Percentage  Retail_Price
# ...

# %% [markdown]
# **Label-Based Selection**

# %%
# akses baris dengan kolom "REGION"

df.loc[195, "Region"]
# Out:
# 'Europe'

# %%
# akses baris 0 sampai 4 dengan kolom "Product_Line"

df.loc[0:5,"Product_Line"]
# Out:
# 0             Gym Sack
# 1                 Hats
# 2          Tech Fleece
# 3        Vapor Cricket
# 4    Performance Socks
# 5              Dri-FIT
# Name: Product_Line, dtype: object

# %%
# akses semua baris dengan urutan kolom "Region" dan "Product_Line"

df.loc[:,["Region","Product_Line"]]
# Out:
#             Region       Product_Line
# 0            India           Gym Sack
# 1            India               Hats
# 2            India        Tech Fleece
# 3    Greater China      Vapor Cricket
# 4    Greater China  Performance Socks
# ..             ...                ...
# 995          India               Hats
# 996         Europe  Performance Socks
# 997          Japan     Phantom Vision
# 998    South Korea         Crew Socks
# 999          Japan      Vapor Cricket
#
# [1000 rows x 2 columns]

# %%
# akses 10 baris teratas kolom "Region" dan "Product_Line"

df[["Region","Product_Line"]][:10]
# Out:
#           Region       Product_Line
# 0          India           Gym Sack
# 1          India               Hats
# 2          India        Tech Fleece
# 3  Greater China      Vapor Cricket
# 4  Greater China  Performance Socks
# 5          Japan            Dri-FIT
# 6          Japan      Vapor Cricket
# 7  Greater China         Therma-FIT
# 8  Greater China      Vapor Cricket
# 9         Europe      Vapor Cricket

# %% [markdown]
# **SLEKSI DATAFRAME BERDASARKAN KONDISI TERTENTU**

# %%
# seleksi baris dengan region "japan"

df["Region"] == "Japan"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997     True
# 998    False
# 999     True
# Name: Region, Length: 1000, dtype: bool

# %%
# menampilkan data dengan kolom region japan

df.loc[df["Region"] == "Japan"]
# Out:
#          Month Region Main_Category Sub_Category    Product_Line Price_Tier  \
# 5      October  Japan       Apparel  Performance         Dri-FIT    Premium
# 6     December  Japan      Footwear      Cricket   Vapor Cricket     Budget
# 20       March  Japan       Apparel    Outerwear      Windrunner  Mid-Range
# 30   September  Japan      Footwear   Basketball      Air Jordan     Budget
# 34     October  Japan     Equipment         Bags        Backpack    Premium
# ..         ...    ...           ...          ...             ...        ...
# 989       June  Japan      Footwear     Football       Mercurial     Budget
# 990      April  Japan     Equipment  Accessories            Hats    Premium
# 994  September  Japan       Apparel         Tops     Tech Fleece    Premium
# 997     August  Japan      Footwear     Football  Phantom Vision    Premium
# 999   December  Japan      Footwear      Cricket   Vapor Cricket  Mid-Range
#
# ...

# %%
# menampilkan data dengan region "japan" dan Price_Tier "Premium"

df.loc[(df["Region"] == "Japan") & (df["Price_Tier"] == "Premium")]
# Out:
#          Month Region Main_Category Sub_Category       Product_Line  \
# 5      October  Japan       Apparel  Performance            Dri-FIT
# 34     October  Japan     Equipment         Bags           Backpack
# 61        June  Japan     Equipment  Accessories               Bags
# 62     October  Japan       Apparel  Performance            Dri-FIT
# 93    November  Japan     Equipment         Bags           Gym Sack
# 105      March  Japan       Apparel    Outerwear        Rain Jacket
# 162   December  Japan      Footwear   Basketball          KD Series
# 165   November  Japan     Equipment  Accessories               Bags
# 169   February  Japan     Equipment  Accessories               Bags
# 175      April  Japan     Equipment  Accessories               Hats
# 278   December  Japan       Apparel         Tops         Therma-FIT
# 281    October  Japan       Apparel    Outerwear        Rain Jacket
# 302    October  Japan      Footwear    Lifestyle             Blazer
# ...

# %% [markdown]
# **Method isin()
# untuk mengecek apakah suatu nilai ada pada data dataset tertentu**

# %%
df.loc[df["Region"].isin(["Japan","South Korea"])].head(10)
# Out:
#         Month       Region Main_Category Sub_Category       Product_Line  \
# 5     October        Japan       Apparel  Performance            Dri-FIT
# 6    December        Japan      Footwear      Cricket      Vapor Cricket
# 11       June  South Korea     Equipment        Socks  Performance Socks
# 20      March        Japan       Apparel    Outerwear         Windrunner
# 27      March  South Korea       Apparel    Outerwear         Windrunner
# 30  September        Japan      Footwear   Basketball         Air Jordan
# 31       June  South Korea     Equipment        Socks  Performance Socks
# 34    October        Japan     Equipment         Bags           Backpack
# 40   February  South Korea       Apparel  Performance   Compression Wear
# 41    October        Japan      Footwear      Running           Air Zoom
#
#    Price_Tier  Units_Sold  Revenue_USD  Online_Sales_Percentage  Retail_Price
# 5     Premium       39344      5508160                       73           140
# ...

# %% [markdown]
# **Method isna() untuk mengecek apakah suatu nilai NULL**

# %%
df.isna().sum()
# Out:
# Month                      0
# Region                     0
# Main_Category              0
# Sub_Category               0
# Product_Line               0
# Price_Tier                 0
# Units_Sold                 0
# Revenue_USD                0
# Online_Sales_Percentage    0
# Retail_Price               0
# dtype: int64

# %% [markdown]
# **Method notna() untuk memeriksa nilai yang tidak NULL**

# %%
df.notna().sum()
# Out:
# Month                      1000
# Region                     1000
# Main_Category              1000
# Sub_Category               1000
# Product_Line               1000
# Price_Tier                 1000
# Units_Sold                 1000
# Revenue_USD                1000
# Online_Sales_Percentage    1000
# Retail_Price               1000
# dtype: int64

# %% [markdown]
# **MENAMBAH KOLOM BARU PADA DATAFRAME**

# %%
# menambah kolom baru "year" dengan nilai 2024 tiap bairs
df["Year"]=2024
df
# Out:
#         Month         Region Main_Category Sub_Category       Product_Line  \
# 0    November          India     Equipment         Bags           Gym Sack
# 1     January          India     Equipment  Accessories               Hats
# 2     October          India       Apparel         Tops        Tech Fleece
# 3    December  Greater China      Footwear      Cricket      Vapor Cricket
# 4         May  Greater China     Equipment        Socks  Performance Socks
# ..        ...            ...           ...          ...                ...
# 995   October          India     Equipment  Accessories               Hats
# 996      July         Europe     Equipment        Socks  Performance Socks
# 997    August          Japan      Footwear     Football     Phantom Vision
# 998       May    South Korea     Equipment        Socks         Crew Socks
# 999  December          Japan      Footwear      Cricket      Vapor Cricket
#
#     Price_Tier  Units_Sold  Revenue_USD  Online_Sales_Percentage  \
# ...

# %%
# memindahkan kolom "year" disamping kolom "month"

col = df.pop("Year")   # ambil kolom year
df.insert(1, "Year", col)  # masukkan di posisi index 1
df
# Out:
#         Month  Year         Region Main_Category Sub_Category  \
# 0    November  2024          India     Equipment         Bags
# 1     January  2024          India     Equipment  Accessories
# 2     October  2024          India       Apparel         Tops
# 3    December  2024  Greater China      Footwear      Cricket
# 4         May  2024  Greater China     Equipment        Socks
# ..        ...   ...            ...           ...          ...
# 995   October  2024          India     Equipment  Accessories
# 996      July  2024         Europe     Equipment        Socks
# 997    August  2024          Japan      Footwear     Football
# 998       May  2024    South Korea     Equipment        Socks
# 999  December  2024          Japan      Footwear      Cricket
#
#           Product_Line Price_Tier  Units_Sold  Revenue_USD  \
# 0             Gym Sack     Budget       48356     14506800
# 1                 Hats     Budget        9842      2066820
# ...

# %% [markdown]
# **MENYIMPAN DATAFRAME KE DALAM FILE CSV**

# %%
# MENYIMPAN DATAFRAME DENGEN MENYERTAKAN INDEKS KE DALAM FILE DENGAN NAMA NIKE_SALES1.CSV

nike_sales1=df.to_csv("Nike_Sales1.csv")
nike_sales1

# %%
# MENYIMPAN DATAFRAME TANPA INDEKS KE DALAM FILE DENGAN NAMA NIKE_SALES2.CSV

nike_sales2=df.to_csv("Nike_Sales2.csv", index=False)
nike_sales2
